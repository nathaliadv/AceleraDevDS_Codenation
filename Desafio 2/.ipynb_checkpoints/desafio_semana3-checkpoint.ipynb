# %% [markdown]
# # Objetivo
#
# Queremos conhecer melhor nossos clientes por estado. Para isso, iniciamos uma análise na pontuação de crédito. Para realizar a verificação inicial, precisamos de alguns valores. Os valores são a média, a mediana, a moda e o desvio padrão da pontuação de crédito.

# %% [markdown]
# # Descrição dos dados:
#
# 'id': Identificador do cliente
#
# 'sobrenome': Sobrenome do cliente
#
# 'pontuacao_credito': Pontuação de crédito do cliente (quanto maior, melhor o cliente geralmente)
#
# 'estado_residencia': Estado de residência do cliente
#
# 'genero': Gênero do cliente
#
# 'nivel_estabilidade': Nível de estabilidade do cliente
#
# 'saldo_conta': Saldo disponível na conta do cliente
#
# 'numero_produtos': Número de produtos que o cliente consome
#
# 'possui_cartao_de_credito': Possui um cartão de crédito cadastrado
#
# 'membro_ativo': Membro acessa e consome frequentemente

# %%
import pandas as pd
import numpy as np
from scipy.stats import mode
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("desafio1.csv")

# %%
df.head(5)
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# 2                SC      F     42                   8    159660.80
# 3                SC      F     39                   1         0.00
# 4                RS      F     43                   2    125510.82
#
#    numero_produtos  possui_cartao_de_credito  membro_ativo
# 0                1                         1             1
# 1                1                         0             1
# 2                3                         1             0
# 3                2                         0             0
# 4                1                         1             1

# %%
df.shape
# Out:
# (7000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   RowNumber                 7000 non-null   int64
#  1   id                        7000 non-null   object
#  2   sobrenome                 7000 non-null   object
#  3   pontuacao_credito         7000 non-null   int64
#  4   estado_residencia         7000 non-null   object
#  5   genero                    7000 non-null   object
#  6   idade                     7000 non-null   int64
#  7   nivel_estabilidade        7000 non-null   int64
#  8   saldo_conta               7000 non-null   float64
#  9   numero_produtos           7000 non-null   int64
#  10  possui_cartao_de_credito  7000 non-null   int64
#  11  membro_ativo              7000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 656.4+ KB

# %%
df.describe()
# Out:
#          RowNumber  pontuacao_credito        idade  nivel_estabilidade  \
# count  7000.000000        7000.000000  7000.000000         7000.000000
# mean   3500.500000         649.787000    38.892714            5.010286
# std    2020.870275          97.046279    10.465562            2.887500
# min       1.000000         350.000000    18.000000            0.000000
# 25%    1750.750000         582.000000    32.000000            3.000000
# 50%    3500.500000         651.000000    37.000000            5.000000
# 75%    5250.250000         717.000000    44.000000            7.250000
# max    7000.000000         850.000000    92.000000           10.000000
#
#          saldo_conta  numero_produtos  possui_cartao_de_credito  membro_ativo
# count    7000.000000      7000.000000               7000.000000   7000.000000
# mean    76471.883751         1.526000                  0.703286      0.512143
# std     62403.383911         0.583047                  0.456842      0.499888
# min         0.000000         1.000000                  0.000000      0.000000
# 25%         0.000000         1.000000                  0.000000      0.000000
# 50%     97277.130000         1.000000                  1.000000      1.000000
# 75%    127537.155000         2.000000                  1.000000      1.000000
# max    250898.090000         4.000000                  1.000000      1.000000

# %%
#Quantidade de clientes de cada sexo por Estado

sexo_estado = df.groupby(['estado_residencia', 'genero']).agg({'id':'count'})
sexo_estado
# Out:
#                             id
# estado_residencia genero
# PR                F        819
#                   M        912
# RS                F        791
#                   M        959
# SC                F       1599
#                   M       1920

# %%
sexo_estado.plot(kind = 'bar', title = "Gênero do cliente por Estado")

# %%
#Número de membros ativos por sexo em cada Estado

sexo_ativo = df.groupby(['estado_residencia', 'genero', 'membro_ativo']).agg({'id':'count'})
sexo_ativo
# Out:
#                                         id
# estado_residencia genero membro_ativo
# PR                F      0             433
#                          1             386
#                   M      0             441
#                          1             471
# RS                F      0             382
#                          1             409
#                   M      0             445
#                          1             514
# SC                F      0             783
#                          1             816
#                   M      0             931
#                          1             989

# %%
#Média de idade de cada gênero por Estado

sexo_idade = df.groupby(['estado_residencia', 'genero']).agg({'idade':'mean'}).round()
sexo_idade
# Out:
#                           idade
# estado_residencia genero
# PR                F        40.0
#                   M        39.0
# RS                F        39.0
#                   M        39.0
# SC                F        39.0
#                   M        38.0

# %%
sexo_idade.plot(kind = 'bar', title = 'Média de idade x Gênero x Estado', legend=False)

# %%
#Número de clientes por Estado

cliente_estado = df.groupby('estado_residencia').agg({'id':'count'})
cliente_estado
# Out:
#                      id
# estado_residencia
# PR                 1731
# RS                 1750
# SC                 3519

# %%
cliente_estado.plot(kind = 'bar', title = 'Clientes por Estado', legend=False)

# %%
#Membro igual a 1: acessa e consome frequentemente
#Quantidade de membros ativos e inativos por estado

ativo_estado = df.groupby(['estado_residencia', 'membro_ativo']).agg({'id':'count'})
ativo_estado
# Out:
#                                   id
# estado_residencia membro_ativo
# PR                0              874
#                   1              857
# RS                0              827
#                   1              923
# SC                0             1714
#                   1             1805

# %%
ativo_estado.plot(kind = 'bar', title = 'Membro ativo e inativo por Estado', legend=False)

# %%
#DataFrame auxiliar apenas com os dados de pontuacao_credito e estado_residencia

df_estado_credito = df[['pontuacao_credito','estado_residencia']]
df_estado_credito
# Out:
#       pontuacao_credito estado_residencia
# 0                   619                SC
# 1                   608                RS
# 2                   502                SC
# 3                   699                SC
# 4                   850                RS
# ...                 ...               ...
# 6995                633                SC
# 6996                623                RS
# 6997                611                SC
# 6998                666                RS
# 6999                521                SC
#
# [7000 rows x 2 columns]

# %%
#DataFrame com os dados de quantidade de clientes por Estado e média, mediana, moda e desvio padrão da pontuação de credito

pontuacao_estado = df.groupby('estado_residencia').agg({'id': 'count','pontuacao_credito':['mean', 'median', pd.Series.mode, 'std']})
pontuacao_estado
# Out:
#                      id pontuacao_credito
#                   count              mean median mode        std
# estado_residencia
# PR                 1731        648.961294    650  850  98.607186
# RS                 1750        651.105143    650  850  95.136598
# SC                 3519        649.537653    653  850  97.233493

# %%
#DataFrame apenas com média, mediana, moda e desvio padrão da pontuação de crédito por Estado

df_to_json = pontuacao_estado['pontuacao_credito']
df_to_json.columns = ['media','mediana','moda','desvio_padrao']
df_to_json
# Out:
#                         media  mediana  moda  desvio_padrao
# estado_residencia
# PR                 648.961294      650   850      98.607186
# RS                 651.105143      650   850      95.136598
# SC                 649.537653      653   850      97.233493

# %%
# Criando o Json de Submissão

df_to_json.to_json('submission.json', orient='index')

# %%
pd.read_json('submission.json')
# Out:
#                        PR          RS          SC
# media          648.961294  651.105143  649.537653
# mediana        650.000000  650.000000  653.000000
# moda           850.000000  850.000000  850.000000
# desvio_padrao   98.607186   95.136598   97.233493

# %% [markdown]
# # Pontuação de crédito
#
# Considerando:
#
# Score entre 701 e 1.000 pontos: Baixo risco de inadimplência
#
# Score entre 301 e 700 pontos: Médio risco de inadimplência
#
# Score entre 0 e 300 pontos: Alto risco de inadimplência

# %%
df['score'] = ['alto' if x > 701 else 'baixo' if x<301 else 'medio' for x in df['pontuacao_credito']]
df.head()
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# 2                SC      F     42                   8    159660.80
# 3                SC      F     39                   1         0.00
# 4                RS      F     43                   2    125510.82
#
#    numero_produtos  possui_cartao_de_credito  membro_ativo  score
# 0                1                         1             1  medio
# 1                1                         0             1  medio
# 2                3                         1             0  medio
# 3                2                         0             0  medio
# 4                1                         1             1   alto

# %%
#Em cada tipo de score (alto e médio) quantos membros são ativos e inativos em cada Estado

ativo_score = df.groupby(['estado_residencia','score']).agg({'membro_ativo':'count'})
ativo_score
# Out:
#                          membro_ativo
# estado_residencia score
# PR                alto            532
#                   medio          1199
# RS                alto            532
#                   medio          1218
# SC                alto           1072
#                   medio          2447

# %%
ativo_score.plot(kind ='bar', title = 'Membros ativos e inativos por Score em cada Estado')

# %%
#Quantidade de clientes por sexo

cliente_sexo = df.groupby('genero').agg({'id':'count'})
cliente_sexo
# Out:
#           id
# genero
# F       3209
# M       3791

# %%
#Quantidade de membros por Score em cada  gênero

sexo_score = df.groupby(['genero', 'score']).agg({'id':'count'})
sexo_score
# Out:
#                 id
# genero score
# F      alto    966
#        medio  2243
# M      alto   1170
#        medio  2621

# %% [markdown]
# # Correlação

# %%
df[['pontuacao_credito', 'saldo_conta']].corr()
# Out:
#                    pontuacao_credito  saldo_conta
# pontuacao_credito           1.000000     0.009761
# saldo_conta                 0.009761     1.000000

# %%
sns.scatterplot(x='pontuacao_credito', y='saldo_conta', data= df)

# %%
df.corr()
# Out:
#                           RowNumber  pontuacao_credito     idade  \
# RowNumber                  1.000000          -0.009068 -0.001710
# pontuacao_credito         -0.009068           1.000000 -0.002839
# idade                     -0.001710          -0.002839  1.000000
# nivel_estabilidade        -0.018256           0.007233 -0.002389
# saldo_conta               -0.016261           0.009761  0.027459
# numero_produtos            0.001250           0.000996 -0.040531
# possui_cartao_de_credito  -0.017742          -0.007987 -0.010335
# membro_ativo               0.007042           0.033992  0.093664
#
#                           nivel_estabilidade  saldo_conta  numero_produtos  \
# RowNumber                          -0.018256    -0.016261         0.001250
# pontuacao_credito                   0.007233     0.009761         0.000996
# idade                              -0.002389     0.027459        -0.040531
# nivel_estabilidade                  1.000000    -0.020527         0.018088
# saldo_conta                        -0.020527     1.000000        -0.303407
# numero_produtos                     0.018088    -0.303407         1.000000
# possui_cartao_de_credito            0.036107    -0.019398        -0.007240
# membro_ativo                       -0.029980    -0.006482         0.007005
#
#                           possui_cartao_de_credito  membro_ativo
# RowNumber                                -0.017742      0.007042
# pontuacao_credito                        -0.007987      0.033992
# idade                                    -0.010335      0.093664
# nivel_estabilidade                        0.036107     -0.029980
# saldo_conta                              -0.019398     -0.006482
# numero_produtos                          -0.007240      0.007005
# possui_cartao_de_credito                  1.000000     -0.014564
# membro_ativo                             -0.014564      1.000000

# %%
df_aux = df._get_numeric_data()

# %%
sns.heatmap(df_aux, annot=True, cmap="YlGnBu")
